# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

driver.get("https://www.basketball-reference.com/players/j/jamesle01.html")

soup = BeautifulSoup(driver.page_source, 'html.parser')

driver.quit()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 109.0.5414
# [WDM] - Get LATEST chromedriver version for 109.0.5414 google-chrome
# [WDM] - Driver [/Users/jeremydumalig/.wdm/drivers/chromedriver/mac64/109.0.5414.74/chromedriver] found in cache

# %%
per_game_table = soup.find("table", {"id" : "per_game"})

# %%
table_head = per_game_table.find("thead")
headers = table_head.find_all("th")

column_names = []
for i in headers:
    column_names.append(i.text)
    
column_names = [i.text for i in headers]

# %%
table_body = per_game_table.find("tbody")
rows = table_body.find_all("tr")

# %%
first_row = rows[0]

first_row_elements = first_row.find_all("td")
first_row_elements = [first_row.find("th").text] + [i.text for i in first_row_elements]

# %%
def clean_row(row):
    first_row_elements = row.find_all("td")
    first_row_elements = [row.find("th").text] + [i.text for i in first_row_elements]
    
    return first_row_elements

cleaned_rows = [clean_row(i) for i in rows]

# %%
lebron = pd.DataFrame(cleaned_rows, columns=column_names)

lebron#.to_csv("lebron.csv")
# Out:
#      Season Age   Tm   Lg Pos   G  GS    MP    FG   FGA  ...   FT%  ORB  DRB  \
# 0   2003-04  19  CLE  NBA  SG  79  79  39.5   7.9  18.9  ...  .754  1.3  4.2
# 1   2004-05  20  CLE  NBA  SF  80  80  42.4   9.9  21.1  ...  .750  1.4  6.0
# 2   2005-06  21  CLE  NBA  SF  79  79  42.5  11.1  23.1  ...  .738  0.9  6.1
# 3   2006-07  22  CLE  NBA  SF  78  78  40.9   9.9  20.8  ...  .698  1.1  5.7
# 4   2007-08  23  CLE  NBA  SF  75  74  40.4  10.6  21.9  ...  .712  1.8  6.1
# 5   2008-09  24  CLE  NBA  SF  81  81  37.7   9.7  19.9  ...  .780  1.3  6.3
# 6   2009-10  25  CLE  NBA  SF  76  76  39.0  10.1  20.1  ...  .767  0.9  6.4
# 7   2010-11  26  MIA  NBA  SF  79  79  38.8   9.6  18.8  ...  .759  1.0  6.5
# 8   2011-12  27  MIA  NBA  SF  62  62  37.5  10.0  18.9  ...  .771  1.5  6.4
# 9   2012-13  28  MIA  NBA  PF  76  76  37.9  10.1  17.8  ...  .753  1.3  6.8
# 10  2013-14  29  MIA  NBA  PF  77  77  37.7  10.0  17.6  ...  .750  1.1  5.9
# ...
